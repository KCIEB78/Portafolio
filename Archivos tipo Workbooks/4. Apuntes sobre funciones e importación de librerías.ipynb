# %% [markdown]
# # **Archivo referente a algunas de las funciones básicas que se pueden ejecutar en Python con variables y datos de diferentes tipos**

# %% [markdown]
# 1. En este archivo mencionaré varias funciones que pueden ser utilizadas en variables y diferentes tipos de datos que se pueden ejecutar en Python; estas mismas, siendo funciones basicas que todavía no entrarían en el análisis de datos; pero, pueden ayudarnos a entender y tener más recursos al momento de trabajar con variables
#
# 2. En este archivo ya no usare tanto las comillas "" para resaltar ciertos conceptos que hasta este momento uno ya debe de estar bastante familiarizado; al menos que, sea información o palabras muy importantes que necesite resaltar
#
# 3.

# %% [markdown]
# # **Archivo referente a los diferentes tipos de textos que se pueden insertar en Python**
#
# 1. Para insertar un texto, en Google Colab, basta con ir a la barra de herramientas y seleccionar el símbolo " + " dando click en opción "Texto"
#
# 2. Para insertar un texto en Anaconda - JupyterLab, basta con agregar un bloque con el símbolo " + " de la barra de herramientas y en la misma barra de herramientas
# buscar el recuadro donde se encuentra escrito " Code " y abrir el menú desplegable, dando click en la opción " Markdown ", ésta hará que el bloque
# se convierta en un " Bloque de texto"; si se ejecuta, simplemente convierte lo escrito en texto con un formato predeterminado de Python

# %% [markdown]
# ---

# %% [markdown]
# # **1. Inserción de títulos y subtítulos**
# ---

# %% [markdown]
# ## **1.1. Títulos**

# %% [markdown]
# Para insertar un título en ambos " entornos ", basta con agregar un " # " al inicio de cada línea de texto para que cuente como texto
#
# # **Título de " primer nivel " iniciando con un solo " # "**

# %% [markdown]
# ---

# %% [markdown]
# ## **1.2. Subtítulos de "n" nivel**
#
# Para insertar un subtítulo en ambos " entornos ", basta con agregar un segundo " # " delante del primero para iniciar con los diferentes niveles de subtítulos
#
# ## **Subtítulo de " segundo nivel " iniciando con dos " # "**
#
# Y así sucesivamente con los diferentes " niveles " que se quieran manejar en el documento
#
# ### **Subtítulo de " tercer nivel " iniciando con tres " # "**
# #### **Subtítulo de " cuarto nivel " iniciando con cuatro " # "**
# ##### **Subtítulo de " quinto nivel " iniciando con cinco " # "**
#
# etc...

# %% [markdown]
# ---

# %% [markdown]
# # **2. Inserción de texto, listas de texto, formatos de texto**

# %% [markdown]
# ---

# %% [markdown]
# ## **2.1. Inserción de un " texto simple "**
#
# Para agregar un texto " simple ", basta con escribirlo en el mismo bloque (asegurándose de que el " tipo de bloque " sea " Texto " o " Markdown ")

# %% [markdown]
# ---

# %% [markdown]
# ## **2.2. Listas de texto, símbolos permitidos y NO permitidos**
#
# Para iniciar una " lista de texto ", basta con agregar los símbolos que se utilizarían para una operación de **SUMA, RESTA Y MULTIPLICACIÓN, ANTES** del texto:
#
# ### *2.2.1. Símbolos permitidos para realizar una " lista de elemntos / texto ":*
#
# - Primer elemento de la lista donde se escribió un " - " al inicio
#
# + Segundo elemento de la lista donde se escribió un " + " al inicio
#
# * Tercer elemento de la lista donde se escribió un " * " al inicio
#
# Estos primeros elementos de la lista automáticamente el entorno aplica un color " naranja " al símbolo escrito y convirtíendolo en un " • " (Punto alto) al momento de " ejecutar " el bloque
#
# ### *2.2.2. Símbolos NO permitidos para realizar una " lista de elementos / texto ":*
#
# # Cuarto elemento de la lista; pero, al escribir un " # " al inicio, lo considera un título
#
# / Quinto elemento de la lista; pero, que no acepta la " / " al inicio para considerarlo como ícono de una " lista "
#
# \ Sexto elemento de la lista; pero, que no acepta la " \ " al inicio para considerar como ícono de una " lista "
#
# = Séptimo elemento de la lista; pero, que no acepta el " = " al inicio para considerarlo como ícono de una " lista "
#
# < Octavo elemento de la lista; pero, que no acepta el " < "al inicio para considerarlo como ícono de una " lista "
#
# ~ Noveno elemento de la lista; pero, que no acepta el " ~ " al inicio para considerarlo como ícono de una " lista "
#
# *Estos elementos de la lista solamente son ejemplos en dado caso de escribir otros símbolos aparte*
#
# ### *2.2.3. Símbolos y caracteres especiales aplicables en ambos " entornos ":*
#
# > Decimo elemento de la lista; pero, que al momento de escribir un " > " lo considera una " cita de código "
#
# Este elemento de " cita " se utiliza en diferentes contextos, más abajo se escriben ejemplos
#
# ◦ Undécimo elemento de la lista donde se escribió un " ◦ " (Círculo vacío) al inicio, esta " viñeta o caracter " lo recomendable es buscarlo en internet, copiarlo y pegarlo
#
# → Doceavo elemento de la lista donde se escribió una " → " al inicio, esta " viñeta o caracter " lo recomendable es buscarlo en internet, copiarlo y pegarlo
#
# ✔ Decimo tercer elemento de la lista donde se escribió un " ✔ " al inicio, esta " viñeta o caracter " lo recomendable es buscarlo en internet, copiarlo y pegarlo
#
# 🔹 Decimo cuarto elemento de la lista donde se escribió un " 🔹 " al inicio, esta " viñeta o caracter " lo recomendable es buscarlo en internet, copiarlo y pegarlo
#
# ✅ Decimo quinto elemento de la lista donde se escribió un " ✅ " al inicio, esta " viñeta o caracter " lo recomendable es buscarlo en internet, copiarlo y pegarlo
#
# ⚠ Decimo sexto elemento de la lista donde se escribió un " ⚠ " al inicio, esta " viñeta o caracter " lo recomendable es buscarlo en internet, copiarlo y pegarlo
#
# Estos elementos al ser caracteres especiales, aunque el " entorno " si los acepta y los " ejecuta " tal cual como son, lo recomendable es solamente usarlos en documentaciones o archivos donde solamente se realicen " notas " o inclusive " manuales de uso "
#
# ### *2.2.4. Directamente colocar el " punto alto " • para escribir una " lista de elementos / texto ":*
#
# • Decimo séptimo elemento de la lista donde se escribió directamente un " • " (Punto alto) al inicio

# %% [markdown]
# ---

# %% [markdown]
# ## **2.3. Formatos de texto**
#
# ---
#
# ### *2.3.1. Formato de texto " NEGRITAS ":*
#
# Para agregar un texto en **" negritas "**, basta con agregar dos " * " **AL INICIO, AL FINAL Y PEGADO al mismo texto**:
#
# - **Texto en negritas de ejemplo** - En dado caso de haberlo escrito correctamente se notará automáticamente que el " entorno " lo detecta como un texto en negritas
#
# - ** Texto de ejemplo en dado caso de NO haberlo exrito correctamente**
#
# - **Segundo texto de ejemplo en dado caso de NO haberlo escrito correctamente **
#
# En dado caso de querer aplicarlo en medio de un texto, basta con agregar los " * " entre el texto en el que se quiera aplicar el formato
#
# - Texto de ejemplo **donde se aplica el formato** en medio del mismo correctamente.
#
# - Texto de ejemplo ** en dado caso de NO haberlo escrito correctamente**
#
# Si se quisiera aplicar el formato de texto **" negritas "** a un **" título "** o **" subtítulo "**, basta con escribirlo después del **" # "** y aplicar la misma regla en dado caso de querer aplicarlo en medio de los mismos
#
# # **Título de ejemplo con el formato de texto " Negritas "**
#
# # **Título de ejemplo en dado caso de NO haberlo escrito correctamente **
#
# # Título de ejemplo **donde se aplica el formato** en medio del mismo correctamente
#
# # Título de ejemplo ** donde NO se aplica correctamente** el formato
#
# #### **Subtítulo de ejemplo con el formato de texto " Negritas "**
#
# #### ** Subtítulo de ejemplo en dado caso de NO haberlo escrito correctamente**
#
# #### Subtítulo de ejemplo **donde se aplica el formato** en medio del mismo correctamente
#
# #### Subtítulo de ejemplo **donde NO se aplica correctamente ** el formato
#
# ---
#
# ### *2.3.2. Formato de texto **" Cursiva "**:*
#
# Para agregar un texto en " cursiva " basta con agregar un solo " * " **AL INICIO, AL FINAL Y PEGADO al mismo texto**:
#
# - *Texto en cursiva de ejemplo* - En dado caso de haberlo escrito correctamente se notará automáticamente que el " entorno " lo detecta como un texto en cursiva
#
# - *Texto de ejemplo en dado caso de NO haberlo escrito correctamente *
#
# - * Segundo texto de ejemplo en dado caso de NO haberlo escrito correctamente*
#
# En dado caso de querer aplicarlo en medio de un texto, basta con agregar el " * " entre el texto en el que se quiera aplicar el formato
#
# - Texto de ejemplo *donde se aplica el formato* en medio del mismo correctamente.
#
# - Texto de ejemplo *en dado caso de NO haberlo escrito correctamente *
#
# - Segundo texto de ejemplo * en dado caso de NO haberlo escrito correctamente*
#
# Si se quisiera aplicar el formato de texto *" cursiva "* a un *" título "* o *" subtítulo "*, basta con escribirlo después del *" # "* y aplicar la misma regla en dado caso de querer aplicarlo en medio de los mismos
#
# # *Título de ejemplo con el formato de texto " Cursiva "*
#
# # *Título de ejemplo en dado caso de NO haberlo escrito correctamente *
#
# # Título de ejemplo *donde se aplica el formato* en medio del mismo correctamente
#
# # Título de ejemplo *donde NO se aplica correctamente * el formato
#
# #### *Subtítulo de ejemplo con el formato de texto " Cursiva "*
#
# #### * Subtítulo de ejemplo en dado caso de NO haberlo escrito correctamente*
#
# #### Subtítulo de ejemplo *donde se aplica el formato* en medio del mismo correctamente
#
# #### Subtítulo de ejemplo * donde NO se aplica correctamente* el formato
#
# ---
#
# ### *<u>2.3.3. Formato de texto " subrayado ":* </u>
#
# Para aplicar un "subrayado" al texto, se debe de aplicar una " Etiqueta HTML " que permite aplciar este formato; para esto, se debe de escribir " < "," u ", " > " **AL INICIO** del texto; pero, para evitar que siga subrayando todo lo demás del bloque, se debe de escribir " < ", " / ", " u ", " > " **AL FINAL** del texto al que se le aplicó el formato
#
# - <u> Texto de ejemplo donde se aplica la " Etiqueta HTML " correctamente y se cierra </u>
#
# - <u> Texto de ejemplo en donde se aplica la " Etiqueta HTML "; pero
# NO SE CERRÓ correctamente </u>
#
# Para aplicar el subrayado a un título o subtítulo es necesario escribir " < "," u ", " > " **DESPUES** del " # "
#
# # <u>Título de ejemplo donde se aplica la " Etiqueta HTML " correctamente y se cierra </u>
#
# # <u> Título de ejemplo donde se aplica la " Etiqueta HTML "; pero
# # no se cerró correctamente y sigue subrayando el título
# ## subtítulo
# o texto de otras líneas </u>
#
# #### <u>Subtítulo de ejemplo donde se aplica la " Etiqueta HTML " correctamente y se cierra </u>
#
# #### <u> Subtítulo de ejemplo donde se aplica la " Etiqueta HTML "; pero
# #### no se cerró correctamente y sigue subrayando el subtítulo
# o texto de otra línea </u>
#
# Para aplicar el subrayado en medio de un texto o título es necesario agregar un " < ", " / ", " u ", " > " **PEGADO A LA ÚLTIMA PALABRA** del texto que se quiera subrayar
#
# - Texto de ejemplo donde <u> se aplica el formato de subrayado</u> en medio del texto correctamente
#
# - Texto de ejemplo donde <u>no se agrega el " < ", " / ", " u ", " > " al final del texto que se quiera subrayar, lo mismo sucede si solamente se escribe " < " " u " " > " sin la " / " </u>
#
# En este caso, si se quiere agregar otro " < "," u ", " > " en medio del texto, se tiene el mismo problema en caso de no cerrar correctamente el subrayado
#
# La misma regla aplica cuando queremos escribir títulos o subtítulos con la misma intención
#
# # Título de ejemplo donde <u> se aplica correctamente</u> el formato "Subrayado" en medio de un título
#
# # Título de ejemplo donde <u> NO se aplica correctamente el formato "Subrayado" en medio de un título </u>
#
# ### Subtítulo de ejemplo donde <u> se aplica correctamente</u> el formato "Subrayado" en medio de un subtítulo
#
# ### Subtítulo de ejemplo donde <u> NO se aplica correctamente el formato "Subrayado" en medio de un título </u>
#
# ---
#
# ### <u>***2.3.4.Combinación de formatos:*** </u>
#
# #### *2.3.4.1. Combinación de formatos en texto:*
#
# Para aplicar la combinación de formatos, basta con escribir PRIMERO los " * " y DESPUÉS " < "," u ", " > " para aplicar el subrayado, SIN OLVIDAR cerrar correctamente el subrayado
#
# - *Texto de ejemplo donde solamente se aplica el formato " Cursiva "*
#
# - ***Texto de ejemplo donde se aplican los formatos " Negritas " y " Cursiva "***; para esto solamente hay que escribir tres " * " juntos
#
# - *<u>Texto de ejemplo donde se aplica el formato " Subrayado " y " Cursiva "* </u>
#
# - **Texto de ejemplo donde solamente se aplica el formato " Negrita "**
#
# - **<u> Texto de ejemplo donde aplica el formato " Subrayado " y " Negrita "** </u>
#
# - <u> Texto de ejemplo donde solamente se aplica el formato " Subrayado " </u>
#
# - <u>***Texto de ejemplo donde se aplican correctamente los tres formatos: " Negrita ", " Cursiva " y " Subrayado "*** </u>
#
# #### *2.3.4.2. Combinación de formatos en títulos y subtítulos:*
#
# En el caso de los títulos y subtítulos, la regla se aplica de igual manera; pero, primero se escribe el " # "
#
# # *Título de ejemplo donde solamente se aplica el formato " Cursiva "*
#
# # ***Título de ejemplo donde se aplican los formatos " Negritas " y " Cursiva "***
# Para esto solamente hay que escribir tres " * " juntos
#
# # *<u> Título de ejemplo donde se aplica el formato " Subrayado " y " Cursiva "* </u>
#
# # **Título de ejemplo donde solamente se aplica el formato " Negrita "**
#
# # **<u> Título de ejemplo donde aplica el formato " Subrayado " y " Negrita "** </u>
#
# # <u> Título de ejemplo donde solamente se aplica el formato " Subrayado " </u>
#
# # <u>***Título de ejemplo donde se aplican correctamente los tres formatos: " Negrita ", " Cursiva " y " Subrayado "*** </u>
#
# #### *Subtítulo de ejemplo donde solamente se aplica el formato " Cursiva "*
#
# #### ***Subtítulo de ejemplo donde se aplican los formatos " Negritas " y " Cursiva "***
# Para esto solamente hay que escribir tres " * " juntos
#
# #### *<u> Subtítulo de ejemplo donde se aplica el formato " Subrayado " y " Cursiva "* </u>
#
# #### **Subtítulo de ejemplo donde solamente se aplica el formato " Negrita "**
#
# #### **<u> Subtítulo de ejemplo donde aplica el formato " Subrayado " y " Negrita "** </u>
#
# #### <u> Subtítulo de ejemplo donde solamente se aplica el formato " Subrayado " </u>
#
# #### <u>***Subtítulo de ejemplo donde se aplican correctamente los tres formatos: " Negrita ", " Cursiva " y " Subrayado "*** </u>
#
# Los casos donde no se apliquen correctamente cada uno de los formatos siguen las mismas reglas previamente mencionadas, el no escribir correctamente los " # ", " * ", " < "," u ", " > " y " < ", " / ", " u ", " > " provocan exactamente los mismos errorres

# %% [markdown]
# ---

# %% [markdown]
# # **3. Citas de código**

# %% [markdown]
# ---

# %% [markdown]
# ## **3.1 Uso de las citas de código**
#
# ### *3.1.1. Situaciones:*
#
# Algunas situaciones donde se pueden llegar a utilizar las citas de código son:
#
# - Citas de documentación:
# - Citas de fuentes
# > Sáenz de Jubera Ocón, M. (2021). Ocio y educación. Universidad de La Rioja.
# - Citas de documentos
# > Ministerio de Educación. (2020). Informe anual de educación [Archivo PDF]. Gobierno de México. https://url-ejemplo.com/informe.pdf.
#
# - Notas:
# - Notas importantes del código
# > Este código sirve para calcular el promedio de...
# - Advertencias del código
# > El código puede fallar en dado caso de escribir una palabra en vez de un número
#
# - Explicaciones:
# - Documentación del código
# > Etapa inicial: Establecer variables
# > Etapa de desarrollo: Cálculos para el promedio
# > Etapa final: Visualización del resultado
# - Explicación del código (ya sea una línea en específico o un bloque completo)
# > En esta línea se ocupo una variable donde...
# > Este bloque tiene como objetivo utilizar las variables para...
# - Comparaciónes
# > Esta línea de código realiza la misma acción que...
# - Interpretaciones
# > El resultado de este bloque de código se puede considerar una...
#
# - Apartados:
# - Resumen de un bloque del código
# > Este bloque de código nos solicita primero...
# - Conclusión de un código
# > Este bloque de código nos demuestra los errores...
# - Resumen en dado caso de que el código más bien sea tipo "apunte" o "workbook"
# > Todo este apartado muestra ejemplos o...
# - Conclusión del "apunte" o "workbook"
# > En conclusión, las fórmulas que se utilizan en Python...
#
# - Simulación:
# - Simulación de bloques "Tip"
# > Tip: Utiliza solamente número enteros
# - Simulación del bloque "Info"
# > Info: Para esta fórmula se debe de considerar...
# - Simulación de "voz"
# > JMP: ¿Por qué la gallina cruzo el puerto de Veracruz?
# >
# > JDG: ¿Por qué?
# - Simulación de "dialogo"
# > JMP: ¿Para qué necesito conocer esta función?
# >
# > VCS: Esta función te permitirá...
#
# - Estructura:
# - Estructura de pensamiento y/o títulos
# > Idea principal
# >> Subtítulo
# >>> Descripción
#
# ### *3.1.2. Donde no usar las citas de código:*
#
# Hay que evitar usar las citas de código cuando:
#
# - Se está escribiendo un texto normal (en caso de ser un párrafo SI puede ser utilizado)
# - Se está escribiendo una lista de texto
# - Se está escribiendo un código

# %% [markdown]
# ---

# %% [markdown]
# # 4. Edición de las celdas tipo " texto " o " Markdown "
#
# Para editar o revisar una celda de texto en Google Colab, JupyterLab o Visual Code Studio:
#
# 1. Hacer doble click sobre el mismo texto
#
# 2. Desplazarse en el código con las flechas de navegación (arriba, abajo, izquierda, derecha) y presionar " Enter " para editar el texto desde donde se " ejecuto " o " guardo " la última vez
#
# 3. Hacer click en el " bloque " y presionar " Enter "
#
# Para poder ver el resultado final o " ejecutar " el código de texto para aplicar formatos, títulos, etc..., solamente hay que presionar " ESC "

# %% [markdown]
# ---
